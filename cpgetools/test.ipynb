# %%
from heaps import percolation1,draw_heap,construireTas1

# %%
T=list(range(10))
p=percolation1(T,0)

# %%
draw_heap(T)

# %%
try:
    next(p)
except:
    pass
draw_heap(T)

# %%
T=list(range(10))
q=construireTas1(T)

# %%
try:
    next(q)
except:
    pass
draw_heap(T)
